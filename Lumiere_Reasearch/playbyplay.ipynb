# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playbyplay
jordan_id = 893
jordan_team_id = 1610612741

# %%
# Query for the last regular season game where the Pacers were playing
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable = jordan_team_id,
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game = games[0]
game_id = game['GAME_ID']
game_matchup = game['MATCHUP']

# %%
from nba_api.stats.endpoints import playbyplay
df = playbyplay.PlayByPlay(game_id).get_data_frames()[0]
df.head(10)
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0022201223         2            12                   0       1
# 1  0022201223         4            10                   0       1
# 2  0022201223         7             1                  47       1
# 3  0022201223         9             1                   6       1
# 4  0022201223        10             2                   1       1
# 5  0022201223        11             4                   0       1
# 6  0022201223        12             2                   1       1
# 7  0022201223        13             4                   0       1
# 8  0022201223        14             1                  52       1
# 9  0022201223        16             6                   1       1
#
#   WCTIMESTRING PCTIMESTRING                                HOMEDESCRIPTION  \
# 0      1:13 PM        12:00                                           None
# 1      1:13 PM        12:00   Jump Ball Vucevic vs. Wiseman: Tip to LaVine
# 2      1:13 PM        11:40        DeRozan 9' Turnaround Jump Shot (2 PTS)
# 3      1:14 PM        11:18                                           None
# 4      1:14 PM        11:02                      MISS LaVine 21' Jump Shot
# 5      1:14 PM        10:56                                           None
# 6      1:14 PM        10:53                                           None
# 7      1:14 PM        10:51                  DeRozan REBOUND (Off:0 Def:1)
# 8      1:14 PM        10:48  LaVine Alley Oop Dunk (2 PTS) (DeRozan 1 AST)
# 9      1:14 PM        10:32                Caruso P.FOUL (P1.T1) (M.Smith)
#
#                   NEUTRALDESCRIPTION              VISITORDESCRIPTION  SCORE  \
# 0  Start of 1st Period (1:13 PM EST)                            None   None
# 1                               None                            None   None
# 2                               None                            None  0 - 2
# 3                               None  Hayes 2' Driving Layup (2 PTS)  2 - 2
# 4                               None                            None   None
# 5                               None     Hayes REBOUND (Off:0 Def:1)   None
# 6                               None     MISS Ivey 27' 3PT Jump Shot   None
# 7                               None                            None   None
# 8                               None                            None  2 - 4
# 9                               None                            None   None
#
#   SCOREMARGIN
# 0        None
# 1        None
# 2           2
# 3         TIE
# 4        None
# 5        None
# 6        None
# 7        None
# 8           2
# 9        None

# %%
import pandas
pandas.set_option('display.max_colwidth',500)
pandas.set_option('display.max_rows',500)

# %%
from enum import Enum

class EventMsgType(Enum):
    FIELD_GOAL_MADE = 1
    FIELD_GOAL_MISSED = 2
    FREE_THROWfree_throw_attempt = 3
    REBOUND = 4
    TURNOVER = 5
    FOUL = 6
    VIOLATION = 7
    SUBSTITUTION = 8
    TIMEOUT = 9
    JUMP_BALL = 10
    EJECTION = 11
    PERIOD_BEGIN = 12
    PERIOD_END = 13

# %%
df.loc[df['EVENTMSGTYPE'] == 4].head(5)
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 5   0022201223        11             4                   0       1
# 7   0022201223        13             4                   0       1
# 11  0022201223        20             4                   0       1
# 14  0022201223        24             4                   0       1
# 20  0022201223        34             4                   0       1
#
#    WCTIMESTRING PCTIMESTRING                HOMEDESCRIPTION  \
# 5       1:14 PM        10:56                           None
# 7       1:14 PM        10:51  DeRozan REBOUND (Off:0 Def:1)
# 11      1:15 PM        10:18   Caruso REBOUND (Off:0 Def:1)
# 14      1:15 PM        10:00                           None
# 20      1:17 PM         8:53                           None
#
#    NEUTRALDESCRIPTION             VISITORDESCRIPTION SCORE SCOREMARGIN
# 5                None    Hayes REBOUND (Off:0 Def:1)  None        None
# 7                None                           None  None        None
# 11               None                           None  None        None
# 14               None  Wiseman REBOUND (Off:1 Def:0)  None        None
# 20               None  Wiseman REBOUND (Off:2 Def:0)  None        None

# %%
import re
import operator

#the following expression is specific to EventMsgType 1
p = re.compile('(\s{2}|\' )([\w+ ]+)')

#get the PlayByPlay data from the Pacers game_id
plays = playbyplay.PlayByPlay(game_id).get_normalized_dict()['PlayByPlay']

#declare a few variables
description = ''
event_msg_action_types = {}

#loop over the play by play data
for play in plays:
    if play['EVENTMSGTYPE'] == 1:
        if play['HOMEDESCRIPTION']:
            description = play['HOMEDESCRIPTION']
        else:
            description = play['VISITORDESCRIPTION']
        if p.search(description):
            #do a bit of searching(regex) and a little character magic: underscores and upper case
            event_msg_action = re.sub(' ', '_', p.search(description).groups()[1].rstrip()).upper()
            #Add it to our dictionary
            event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
            
#sort it all
event_msg_action_types = sorted(event_msg_action_types.items(), key=operator.itemgetter(0))

#output a class that we could plug into our code base
for action in event_msg_action_types:
    print(f'\t{action[0]} = {action[1]}')
# Out:
# 	3PT_JUMP_SHOT = 1
# 	3PT_PULLUP_JUMP_SHOT = 79
# 	3PT_STEP_BACK_JUMP_SHOT = 80
# 	CUTTING_LAYUP_SHOT = 98
# 	DRIVING_FINGER_ROLL_LAYUP = 75
# 	DRIVING_FLOATING_BANK_JUMP_SHOT = 102
# 	DRIVING_FLOATING_JUMP_SHOT = 101
# 	DRIVING_HOOK_SHOT = 57
# 	DRIVING_LAYUP = 6
# 	DUNK = 7
# 	FLOATING_JUMP_SHOT = 78
# 	JUMP_SHOT = 1
# 	LAYUP = 5
# 	PULLUP_JUMP_SHOT = 79
# 	RUNNING_LAYUP = 41
# 	STEP_BACK_JUMP_SHOT = 80
# 	TURNAROUND_HOOK_SHOT = 58
# 	TURNAROUND_JUMP_SHOT = 47

# %%
#get the PlayByPlay data from the Pacers game_id
plays = playbyplay.PlayByPlay(game_id).get_normalized_dict()['PlayByPlay']

#declare a few variables
description = ''
event_msg_action_types = {}

#loop over the play by play data
#do a bit of findall(regex) and a little character magic: underscores and upper case
#we're using a findall here as we have to deal with the extra word MISS at the beginning of the text.
#that extra text means we'll have multiple matches for our regex.
for play in plays:
    if play['EVENTMSGTYPE'] == 2:
        match = list()
        if play['HOMEDESCRIPTION'] is not None: 
            match = p.findall(play['HOMEDESCRIPTION'])

            #looking for blocks
            if len(match) & (play['VISITORDESCRIPTION'] is not None):
                print(play['VISITORDESCRIPTION'])

        else:
            match = p.findall(play['VISITORDESCRIPTION'])
            
            #looking for blocks
            if len(match) & (play['HOMEDESCRIPTION'] is not None):
                print(play['HOMEDESCRIPTION'])
        if match:
            event_msg_action = re.sub(' ', '_', match[0][1]).upper()
            event_msg_action_types[event_msg_action] = play['EVENTMSGACTIONTYPE']
            
event_msg_action_types = sorted(event_msg_action_types.items(), key=operator.itemgetter(0))

print("")
for action in event_msg_action_types:
    print(f'{action[0]} = {action[1]}')
# Out:
# Wiseman BLOCK (1 BLK)
# Duren BLOCK (1 BLK)
# Hayes BLOCK (1 BLK)
#
# 3PT_JUMP_SHOT = 1
# 3PT_PULLUP_JUMP_SHOT = 79
# 3PT_STEP_BACK_JUMP_SHOT = 80
# ALLEY_OOP_LAYUP = 43
# DRIVING_DUNK = 9
# DRIVING_FLOATING_BANK_JUMP_SHOT = 102
# DRIVING_FLOATING_JUMP_SHOT = 101
# DRIVING_HOOK_SHOT = 57
# DRIVING_LAYUP = 6
# DRIVING_REVERSE_LAYUP = 73
# FADEAWAY_JUMPER = 63
# FLOATING_JUMP_SHOT = 78
# JUMP_SHOT = 1
# LAYUP = 5
# PULLUP_JUMP_SHOT = 79
# PUTBACK_LAYUP = 72
# RUNNING_LAYUP = 41
# TIP_LAYUP_SHOT = 97
# TURNAROUND_JUMP_SHOT = 47

# %%
play = pd.read_csv("play_by_play.csv")
play.columns
# Out:
# Index(['game_id', 'eventnum', 'eventmsgtype', 'eventmsgactiontype', 'period',
#        'wctimestring', 'pctimestring', 'homedescription', 'neutraldescription',
#        'visitordescription', 'score', 'scoremargin', 'person1type',
#        'player1_id', 'player1_name', 'player1_team_id', 'player1_team_city',
#        'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
#        'player2_id', 'player2_name', 'player2_team_id', 'player2_team_city',
#        'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
#        'player3_id', 'player3_name', 'player3_team_id', 'player3_team_city',
#        'player3_team_nickname', 'player3_team_abbreviation',
#        'video_available_flag'],
#       dtype='object')

# %%
play["player1_name"]
# Out:
# 0                          NaN
# 1              Hakeem Olajuwon
# 2           Corliss Williamson
# 3              Hakeem Olajuwon
# 4                Clyde Drexler
#                    ...
# 13227006             Ish Smith
# 13227007       Cameron Johnson
# 13227008          Nikola Jokic
# 13227009                   NaN
# 13227010                   NaN
# Name: player1_name, Length: 13227011, dtype: object

# %%
play = play.drop(['player1_name', 'player1_team_abbreviation', 'player2_team_city',
       'player2_team_nickname', 'player2_team_abbreviation', 'player3_name', 'player3_team_id', 'player3_team_city',
       'player3_team_nickname', 'player3_team_abbreviation', 'video_available_flag', 'person1type', 'person2type', 'person3type'], axis = 1)

# %%
play.head(20)
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0   29600009         2            12                   0       1     11:44 PM
# 1   29600009         3            10                   0       1     11:45 PM
# 2   29600009         4             5                   4       1     11:46 PM
# 3   29600009         5             2                   1       1     11:46 PM
# 4   29600009         7             4                   0       1     11:46 PM
# 5   29600009         6             2                   5       1     11:46 PM
# 6   29600009         8             4                   0       1     11:46 PM
# 7   29600009         9             1                   2       1     11:46 PM
# 8   29600009        10             1                   1       1     11:47 PM
# 9   29600009        11             1                   6       1     11:47 PM
# 10  29600009        12             2                   1       1     11:47 PM
# 11  29600009        13             4                   0       1     11:47 PM
# 12  29600009        14             1                   5       1     11:47 PM
# 13  29600009        15             2                   1       1     11:47 PM
# 14  29600009        16             4                   0       1     11:47 PM
# 15  29600009        17             1                   1       1     11:48 PM
# 16  29600009        18             2                   1       1     11:48 PM
# 17  29600009        19             4                   0       1     11:48 PM
# 18  29600009        20             2                   1       1     11:48 PM
# 19  29600009        21             4                   0       1     11:48 PM
#
#    pctimestring                                      homedescription  \
# 0         12:00                                                  NaN
# 1         12:00   Jump Ball Olajuwon vs. Polynice: Tip to Williamson
# 2         11:49                                                  NaN
# 3         11:27                          MISS Olajuwon 13' Jump Shot
# 4         11:23                        Drexler REBOUND (Off:1 Def:0)
# 5         11:23                                  MISS Drexler  Layup
# 6         11:22                       Olajuwon REBOUND (Off:1 Def:0)
# 7         11:18  Elie 10' Running Jump Shot (2 PTS) (Olajuwon 1 AST)
# 8         11:00                                                  NaN
# 9         10:44       Maloney  Driving Layup (2 PTS) (Drexler 1 AST)
# 10        10:27                                                  NaN
# 11        10:26                                                  NaN
# 12        10:21                                                  NaN
# 13        10:10                          MISS Elie 24' 3PT Jump Shot
# 14        10:09                                                  NaN
# 15         9:58                                                  NaN
# 16         9:43                               MISS Elie 9' Jump Shot
# 17         9:42                                                  NaN
# 18         9:35                                                  NaN
# 19         9:33                         Willis REBOUND (Off:0 Def:1)
#
#                     neutraldescription  \
# 0   Start of 1st Period (11:44 PM EST)
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
#
#                                   visitordescription  score scoremargin  \
# 0                                                NaN    NaN         NaN
# 1                                                NaN    NaN         NaN
# 2              Williamson Traveling Turnover (P1.T1)    NaN         NaN
# 3                                                NaN    NaN         NaN
# 4                                                NaN    NaN         NaN
# 5                                                NaN    NaN         NaN
# 6                                                NaN    NaN         NaN
# 7                                                NaN  0 - 2           2
# 8                    Abdul-Rauf 9' Jump Shot (2 PTS)  2 - 2         TIE
# 9                                                NaN  2 - 4           2
# 10                     MISS Williamson 13' Jump Shot    NaN         NaN
# 11                    Polynice REBOUND (Off:1 Def:0)    NaN         NaN
# 12        Williamson  Layup (2 PTS) (Polynice 1 AST)  4 - 4         TIE
# 13                                               NaN    NaN         NaN
# 14                  Williamson REBOUND (Off:0 Def:1)    NaN         NaN
# 15  Williamson 7' Jump Shot (4 PTS) (Richmond 1 AST)  6 - 4          -2
# 16                                               NaN    NaN         NaN
# 17                    Polynice REBOUND (Off:1 Def:1)    NaN         NaN
# 18                    MISS Abdul-Rauf  3PT Jump Shot    NaN         NaN
# 19                                               NaN    NaN         NaN
#
#     player1_id  player1_team_id player1_team_city player1_team_nickname  \
# 0            0              NaN               NaN                   NaN
# 1          165     1.610613e+09           Houston               Rockets
# 2          722     1.610613e+09        Sacramento                 Kings
# 3          165     1.610613e+09           Houston               Rockets
# 4           17     1.610613e+09           Houston               Rockets
# 5           17     1.610613e+09           Houston               Rockets
# 6          165     1.610613e+09           Houston               Rockets
# 7           53     1.610613e+09           Houston               Rockets
# 8           51     1.610613e+09        Sacramento                 Kings
# 9         1074     1.610613e+09           Houston               Rockets
# 10         722     1.610613e+09        Sacramento                 Kings
# 11         178     1.610613e+09        Sacramento                 Kings
# 12         722     1.610613e+09        Sacramento                 Kings
# 13          53     1.610613e+09           Houston               Rockets
# 14         722     1.610613e+09        Sacramento                 Kings
# 15         722     1.610613e+09        Sacramento                 Kings
# 16          53     1.610613e+09           Houston               Rockets
# 17         178     1.610613e+09        Sacramento                 Kings
# 18          51     1.610613e+09        Sacramento                 Kings
# 19         788     1.610613e+09           Houston               Rockets
#
#     player2_id     player2_name  player2_team_id  player3_id
# 0            0              NaN              NaN           0
# 1          178   Olden Polynice     1.610613e+09         722
# 2            0              NaN              NaN           0
# 3            0              NaN              NaN           0
# 4            0              NaN              NaN           0
# 5            0              NaN              NaN           0
# 6            0              NaN              NaN           0
# 7          165  Hakeem Olajuwon     1.610613e+09           0
# 8            0              NaN              NaN           0
# 9           17    Clyde Drexler     1.610613e+09           0
# 10           0              NaN              NaN           0
# 11           0              NaN              NaN           0
# 12         178   Olden Polynice     1.610613e+09           0
# 13           0              NaN              NaN           0
# 14           0              NaN              NaN           0
# 15         782   Mitch Richmond     1.610613e+09           0
# 16           0              NaN              NaN           0
# 17           0              NaN              NaN           0
# 18           0              NaN              NaN           0
# 19           0              NaN              NaN           0

# %%
play
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0         29600009         2            12                   0       1
# 1         29600009         3            10                   0       1
# 2         29600009         4             5                   4       1
# 3         29600009         5             2                   1       1
# 4         29600009         7             4                   0       1
# ...            ...       ...           ...                 ...     ...
# 13227006  22201014       662             8                   0       4
# 13227007  22201014       664             8                   0       4
# 13227008  22201014       666             2                  47       4
# 13227009  22201014       667             4                   0       4
# 13227010  22201014       668            13                   0       4
#
#          wctimestring pctimestring  \
# 0            11:44 PM        12:00
# 1            11:45 PM        12:00
# 2            11:46 PM        11:49
# 3            11:46 PM        11:27
# 4            11:46 PM        11:23
# ...               ...          ...
# 13227006      6:01 PM         0:01
# 13227007      6:01 PM         0:01
# 13227008      6:02 PM         0:00
# 13227009      6:02 PM         0:00
# 13227010      6:02 PM         0:00
#
#                                              homedescription  \
# 0                                                        NaN
# 1         Jump Ball Olajuwon vs. Polynice: Tip to Williamson
# 2                                                        NaN
# 3                                MISS Olajuwon 13' Jump Shot
# 4                              Drexler REBOUND (Off:1 Def:0)
# ...                                                      ...
# 13227006                           SUB: Porter Jr. FOR Smith
# 13227007                                                 NaN
# 13227008             MISS Jokic 25' 3PT Turnaround Jump Shot
# 13227009                                     NUGGETS Rebound
# 13227010                                                 NaN
#
#                           neutraldescription  \
# 0         Start of 1st Period (11:44 PM EST)
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 13227006                                 NaN
# 13227007                                 NaN
# 13227008                                 NaN
# 13227009                                 NaN
# 13227010     End of 4th Period (6:02 PM EST)
#
#                              visitordescription      score scoremargin  \
# 0                                           NaN        NaN         NaN
# 1                                           NaN        NaN         NaN
# 2         Williamson Traveling Turnover (P1.T1)        NaN         NaN
# 3                                           NaN        NaN         NaN
# 4                                           NaN        NaN         NaN
# ...                                         ...        ...         ...
# 13227006                                    NaN        NaN         NaN
# 13227007               SUB: Claxton FOR Johnson        NaN         NaN
# 13227008                                    NaN        NaN         NaN
# 13227009                                    NaN        NaN         NaN
# 13227010                                    NaN  122 - 120          -2
#
#           player1_id  player1_team_id player1_team_city player1_team_nickname  \
# 0                  0              NaN               NaN                   NaN
# 1                165     1.610613e+09           Houston               Rockets
# 2                722     1.610613e+09        Sacramento                 Kings
# 3                165     1.610613e+09           Houston               Rockets
# 4                 17     1.610613e+09           Houston               Rockets
# ...              ...              ...               ...                   ...
# 13227006      202397     1.610613e+09            Denver               Nuggets
# 13227007     1629661     1.610613e+09          Brooklyn                  Nets
# 13227008      203999     1.610613e+09            Denver               Nuggets
# 13227009  1610612743              NaN               NaN                   NaN
# 13227010           0              NaN               NaN                   NaN
#
#           player2_id        player2_name  player2_team_id  player3_id
# 0                  0                 NaN              NaN           0
# 1                178      Olden Polynice     1.610613e+09         722
# 2                  0                 NaN              NaN           0
# 3                  0                 NaN              NaN           0
# 4                  0                 NaN              NaN           0
# ...              ...                 ...              ...         ...
# 13227006     1629008  Michael Porter Jr.     1.610613e+09           0
# 13227007     1629651         Nic Claxton     1.610613e+09           0
# 13227008           0                 NaN              NaN           0
# 13227009           0                 NaN              NaN           0
# 13227010           0                 NaN              NaN           0
#
# [13227011 rows x 20 columns]

# %%
play[play["eventmsgtype"] == 11]
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 6911      29600022       362            11                   3       4
# 20632     29600052       396            11                   1       4
# 69794     29600166       428            11                   1       4
# 70984     29600161       276            11                   1       3
# 92187     29600213       164            11                   1       2
# ...            ...       ...           ...                 ...     ...
# 13184571  22200921       561            11                   4       4
# 13206657  22200975       634            11                   4       4
# 13218008  22201002       421            11                   4       3
# 13218009  22201002       422            11                   4       3
# 13221890  22201008       606            11                   4       4
#
#          wctimestring pctimestring                       homedescription  \
# 6911         12:52 PM         9:59  Horry Ejection:First Flagrant Type 2
# 20632        15:59 PM         8:09    Robinson Ejection:Second Technical
# 69794        11:10 PM         0:13                                   NaN
# 70984        13:07 PM         2:34                                   NaN
# 92187        12:08 PM        11:11                                   NaN
# ...               ...          ...                                   ...
# 13184571      9:53 PM         3:46                                   NaN
# 13206657     11:20 PM         0:28                                   NaN
# 13218008      9:38 PM         6:57                                   NaN
# 13218009      9:38 PM         6:57                Collins Ejection:Other
# 13221890      9:46 PM         1:25                                   NaN
#
#                   neutraldescription                visitordescription score  \
# 6911                             NaN                               NaN   NaN
# 20632                            NaN                               NaN   NaN
# 69794                            NaN  Rodman Ejection:Second Technical   NaN
# 70984      Ejection:Second Technical                               NaN   NaN
# 92187      Ejection:Second Technical                               NaN   NaN
# ...                              ...                               ...   ...
# 13184571                         NaN              Tatum Ejection:Other   NaN
# 13206657                         NaN             Barnes Ejection:Other   NaN
# 13218008                         NaN         Porter Jr. Ejection:Other   NaN
# 13218009                         NaN                               NaN   NaN
# 13221890                         NaN              Smart Ejection:Other   NaN
#
#          scoremargin  player1_id  player1_team_id player1_team_city  \
# 6911             NaN         109     1.610613e+09           Phoenix
# 20632            NaN         361     1.610613e+09          Portland
# 69794            NaN          23     1.610613e+09           Chicago
# 70984            NaN        1242              NaN               NaN
# 92187            NaN  1879048195              NaN               NaN
# ...              ...         ...              ...               ...
# 13184571         NaN     1628369     1.610613e+09            Boston
# 13206657         NaN     1630567     1.610613e+09           Toronto
# 13218008         NaN     1629008     1.610613e+09            Denver
# 13218009         NaN     1628380     1.610613e+09       San Antonio
# 13221890         NaN      203935     1.610613e+09            Boston
#
#          player1_team_nickname  player2_id player2_name  player2_team_id  \
# 6911                      Suns           0          NaN              NaN
# 20632            Trail Blazers           0          NaN              NaN
# 69794                    Bulls           0          NaN              NaN
# 70984                      NaN           0          NaN              NaN
# 92187                      NaN           0          NaN              NaN
# ...                        ...         ...          ...              ...
# 13184571               Celtics           0          NaN              NaN
# 13206657               Raptors           0          NaN              NaN
# 13218008               Nuggets           0          NaN              NaN
# 13218009                 Spurs           0          NaN              NaN
# 13221890               Celtics           0          NaN              NaN
#
#           player3_id
# 6911               0
# 20632              0
# 69794              0
# 70984              0
# 92187              0
# ...              ...
# 13184571           0
# 13206657           0
# 13218008           0
# 13218009           0
# 13221890           0
#
# [1902 rows x 20 columns]

# %%
temp = play.loc[(play["eventmsgtype"] == 8)]

# %%
play.head(50)
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0   29600009         2            12                   0       1     11:44 PM
# 1   29600009         3            10                   0       1     11:45 PM
# 2   29600009         4             5                   4       1     11:46 PM
# 3   29600009         5             2                   1       1     11:46 PM
# 4   29600009         7             4                   0       1     11:46 PM
# 5   29600009         6             2                   5       1     11:46 PM
# 6   29600009         8             4                   0       1     11:46 PM
# 7   29600009         9             1                   2       1     11:46 PM
# 8   29600009        10             1                   1       1     11:47 PM
# 9   29600009        11             1                   6       1     11:47 PM
# 10  29600009        12             2                   1       1     11:47 PM
# 11  29600009        13             4                   0       1     11:47 PM
# 12  29600009        14             1                   5       1     11:47 PM
# 13  29600009        15             2                   1       1     11:47 PM
# 14  29600009        16             4                   0       1     11:47 PM
# 15  29600009        17             1                   1       1     11:48 PM
# 16  29600009        18             2                   1       1     11:48 PM
# 17  29600009        19             4                   0       1     11:48 PM
# 18  29600009        20             2                   1       1     11:48 PM
# 19  29600009        21             4                   0       1     11:48 PM
# 20  29600009        22             1                   1       1     11:48 PM
# 21  29600009        23             2                   5       1     11:49 PM
# 22  29600009        24             4                   0       1     11:49 PM
# 23  29600009        25             2                   1       1     11:49 PM
# 24  29600009        26             4                   0       1     11:49 PM
# 25  29600009        27             2                   1       1     11:49 PM
# 26  29600009        28             4                   0       1     11:49 PM
# 27  29600009        29             2                   5       1     11:49 PM
# 28  29600009        30             4                   0       1     11:49 PM
# 29  29600009        31             7                   6       1     11:50 PM
# 30  29600009        32             2                   5       1     11:50 PM
# 31  29600009        34             4                   0       1     11:50 PM
# 32  29600009        33             2                   1       1     11:50 PM
# 33  29600009        35             4                   0       1     11:50 PM
# 34  29600009        36             5                   4       1     11:50 PM
# 35  29600009        37             5                   1       1     11:51 PM
# 36  29600009        38             1                   1       1     11:51 PM
# 37  29600009        39             6                   1       1     11:51 PM
# 38  29600009        40             1                   1       1     11:52 PM
# 39  29600009        41             2                   1       1     11:52 PM
# 40  29600009        42             4                   0       1     11:52 PM
# 41  29600009        43             6                   2       1     11:52 PM
# 42  29600009        44             9                   1       1     11:52 PM
# 43  29600009        45             8                   0       1     11:54 PM
# 44  29600009        46             3                  11       1     11:54 PM
# 45  29600009        47             3                  12       1     11:55 PM
# 46  29600009        48             1                   5       1     11:55 PM
# 47  29600009        49             6                   2       1     11:55 PM
# 48  29600009        50             3                  10       1     11:55 PM
# 49  29600009        51             1                   1       1     11:56 PM
#
#    pctimestring                                      homedescription  \
# 0         12:00                                                  NaN
# 1         12:00   Jump Ball Olajuwon vs. Polynice: Tip to Williamson
# 2         11:49                                                  NaN
# 3         11:27                          MISS Olajuwon 13' Jump Shot
# 4         11:23                        Drexler REBOUND (Off:1 Def:0)
# 5         11:23                                  MISS Drexler  Layup
# 6         11:22                       Olajuwon REBOUND (Off:1 Def:0)
# 7         11:18  Elie 10' Running Jump Shot (2 PTS) (Olajuwon 1 AST)
# 8         11:00                                                  NaN
# 9         10:44       Maloney  Driving Layup (2 PTS) (Drexler 1 AST)
# 10        10:27                                                  NaN
# 11        10:26                                                  NaN
# 12        10:21                                                  NaN
# 13        10:10                          MISS Elie 24' 3PT Jump Shot
# 14        10:09                                                  NaN
# 15         9:58                                                  NaN
# 16         9:43                               MISS Elie 9' Jump Shot
# 17         9:42                                                  NaN
# 18         9:35                                                  NaN
# 19         9:33                         Willis REBOUND (Off:0 Def:1)
# 20         9:18          Elie  3PT Jump Shot (5 PTS) (Drexler 2 AST)
# 21         8:59                                                  NaN
# 22         8:58                                                  NaN
# 23         8:49                                                  NaN
# 24         8:48                        Drexler REBOUND (Off:1 Def:1)
# 25         8:38                            MISS Willis 11' Jump Shot
# 26         8:37                                                  NaN
# 27         8:24                                                  NaN
# 28         8:23                       Olajuwon REBOUND (Off:1 Def:1)
# 29         8:15                                                  NaN
# 30         8:08                                   MISS Willis  Layup
# 31         8:05                       Olajuwon REBOUND (Off:2 Def:1)
# 32         8:05                           MISS Olajuwon 8' Jump Shot
# 33         8:04                                                  NaN
# 34         7:58                                                  NaN
# 35         7:47                    Drexler Bad Pass Turnover (P1.T1)
# 36         7:28                                                  NaN
# 37         7:11                                                  NaN
# 38         7:03                        Drexler 19' Jump Shot (2 PTS)
# 39         6:47                                                  NaN
# 40         6:46                       Olajuwon REBOUND (Off:2 Def:2)
# 41         6:35                                                  NaN
# 42         6:35            ROCKETS Timeout: Regular (Full 1 Short 0)
# 43         6:35                                                  NaN
# 44         6:35                     Willis Free Throw 1 of 2 (1 PTS)
# 45         6:35                     Willis Free Throw 2 of 2 (2 PTS)
# 46         6:20                                                  NaN
# 47         6:20                              Olajuwon S.FOUL (P1.T1)
# 48         6:20                                                  NaN
# 49         6:07       Maloney  3PT Jump Shot (5 PTS) (Drexler 3 AST)
#
#                     neutraldescription  \
# 0   Start of 1st Period (11:44 PM EST)
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36                                 NaN
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41                                 NaN
# 42                                 NaN
# 43                                 NaN
# 44                                 NaN
# 45                                 NaN
# 46                                 NaN
# 47                                 NaN
# 48                                 NaN
# 49                                 NaN
#
#                                   visitordescription    score scoremargin  \
# 0                                                NaN      NaN         NaN
# 1                                                NaN      NaN         NaN
# 2              Williamson Traveling Turnover (P1.T1)      NaN         NaN
# 3                                                NaN      NaN         NaN
# 4                                                NaN      NaN         NaN
# 5                                                NaN      NaN         NaN
# 6                                                NaN      NaN         NaN
# 7                                                NaN    0 - 2           2
# 8                    Abdul-Rauf 9' Jump Shot (2 PTS)    2 - 2         TIE
# 9                                                NaN    2 - 4           2
# 10                     MISS Williamson 13' Jump Shot      NaN         NaN
# 11                    Polynice REBOUND (Off:1 Def:0)      NaN         NaN
# 12        Williamson  Layup (2 PTS) (Polynice 1 AST)    4 - 4         TIE
# 13                                               NaN      NaN         NaN
# 14                  Williamson REBOUND (Off:0 Def:1)      NaN         NaN
# 15  Williamson 7' Jump Shot (4 PTS) (Richmond 1 AST)    6 - 4          -2
# 16                                               NaN      NaN         NaN
# 17                    Polynice REBOUND (Off:1 Def:1)      NaN         NaN
# 18                    MISS Abdul-Rauf  3PT Jump Shot      NaN         NaN
# 19                                               NaN      NaN         NaN
# 20                                               NaN    6 - 7           1
# 21                                 MISS Grant  Layup      NaN         NaN
# 22                                     Kings Rebound      NaN         NaN
# 23                      MISS Richmond  3PT Jump Shot      NaN         NaN
# 24                                               NaN      NaN         NaN
# 25                                               NaN      NaN         NaN
# 26                    Richmond REBOUND (Off:0 Def:1)      NaN         NaN
# 27                            MISS Williamson  Layup      NaN         NaN
# 28                                               NaN      NaN         NaN
# 29                    Polynice Violation:Double Lane      NaN         NaN
# 30                            Richmond BLOCK (1 BLK)      NaN         NaN
# 31                                               NaN      NaN         NaN
# 32                                               NaN      NaN         NaN
# 33                    Richmond REBOUND (Off:0 Def:2)      NaN         NaN
# 34               Polynice Traveling Turnover (P1.T2)      NaN         NaN
# 35                                               NaN      NaN         NaN
# 36    Grant 17' Jump Shot (2 PTS) (Williamson 1 AST)    8 - 7          -1
# 37                              Grant P.FOUL (P1.T1)      NaN         NaN
# 38                                               NaN    8 - 9           1
# 39                          MISS Grant 17' Jump Shot      NaN         NaN
# 40                                               NaN      NaN         NaN
# 41                              Grant S.FOUL (P2.T2)      NaN         NaN
# 42                                               NaN      NaN         NaN
# 43                              SUB: Smith FOR Grant      NaN         NaN
# 44                                               NaN   8 - 10           2
# 45                                               NaN   8 - 11           3
# 46        Richmond  Layup (2 PTS) (Williamson 2 AST)  10 - 11           1
# 47                                               NaN      NaN         NaN
# 48                Richmond Free Throw 1 of 1 (3 PTS)  11 - 11         TIE
# 49                                               NaN  11 - 14           3
#
#     player1_id  player1_team_id player1_team_city player1_team_nickname  \
# 0            0              NaN               NaN                   NaN
# 1          165     1.610613e+09           Houston               Rockets
# 2          722     1.610613e+09        Sacramento                 Kings
# 3          165     1.610613e+09           Houston               Rockets
# 4           17     1.610613e+09           Houston               Rockets
# 5           17     1.610613e+09           Houston               Rockets
# 6          165     1.610613e+09           Houston               Rockets
# 7           53     1.610613e+09           Houston               Rockets
# 8           51     1.610613e+09        Sacramento                 Kings
# 9         1074     1.610613e+09           Houston               Rockets
# 10         722     1.610613e+09        Sacramento                 Kings
# 11         178     1.610613e+09        Sacramento                 Kings
# 12         722     1.610613e+09        Sacramento                 Kings
# 13          53     1.610613e+09           Houston               Rockets
# 14         722     1.610613e+09        Sacramento                 Kings
# 15         722     1.610613e+09        Sacramento                 Kings
# 16          53     1.610613e+09           Houston               Rockets
# 17         178     1.610613e+09        Sacramento                 Kings
# 18          51     1.610613e+09        Sacramento                 Kings
# 19         788     1.610613e+09           Houston               Rockets
# 20          53     1.610613e+09           Houston               Rockets
# 21         258     1.610613e+09        Sacramento                 Kings
# 22  1610612758              NaN               NaN                   NaN
# 23         782     1.610613e+09        Sacramento                 Kings
# 24          17     1.610613e+09           Houston               Rockets
# 25         788     1.610613e+09           Houston               Rockets
# 26         782     1.610613e+09        Sacramento                 Kings
# 27         722     1.610613e+09        Sacramento                 Kings
# 28         165     1.610613e+09           Houston               Rockets
# 29         178     1.610613e+09        Sacramento                 Kings
# 30         788     1.610613e+09           Houston               Rockets
# 31         165     1.610613e+09           Houston               Rockets
# 32         165     1.610613e+09           Houston               Rockets
# 33         782     1.610613e+09        Sacramento                 Kings
# 34         178     1.610613e+09        Sacramento                 Kings
# 35          17     1.610613e+09           Houston               Rockets
# 36         258     1.610613e+09        Sacramento                 Kings
# 37         258     1.610613e+09        Sacramento                 Kings
# 38          17     1.610613e+09           Houston               Rockets
# 39         258     1.610613e+09        Sacramento                 Kings
# 40         165     1.610613e+09           Houston               Rockets
# 41         258     1.610613e+09        Sacramento                 Kings
# 42  1610612745              NaN               NaN                   NaN
# 43         258     1.610613e+09        Sacramento                 Kings
# 44         788     1.610613e+09           Houston               Rockets
# 45         788     1.610613e+09           Houston               Rockets
# 46         782     1.610613e+09        Sacramento                 Kings
# 47         165     1.610613e+09           Houston               Rockets
# 48         782     1.610613e+09        Sacramento                 Kings
# 49        1074     1.610613e+09           Houston               Rockets
#
#     player2_id        player2_name  player2_team_id  player3_id
# 0            0                 NaN              NaN           0
# 1          178      Olden Polynice     1.610613e+09         722
# 2            0                 NaN              NaN           0
# 3            0                 NaN              NaN           0
# 4            0                 NaN              NaN           0
# 5            0                 NaN              NaN           0
# 6            0                 NaN              NaN           0
# 7          165     Hakeem Olajuwon     1.610613e+09           0
# 8            0                 NaN              NaN           0
# 9           17       Clyde Drexler     1.610613e+09           0
# 10           0                 NaN              NaN           0
# 11           0                 NaN              NaN           0
# 12         178      Olden Polynice     1.610613e+09           0
# 13           0                 NaN              NaN           0
# 14           0                 NaN              NaN           0
# 15         782      Mitch Richmond     1.610613e+09           0
# 16           0                 NaN              NaN           0
# 17           0                 NaN              NaN           0
# 18           0                 NaN              NaN           0
# 19           0                 NaN              NaN           0
# 20          17       Clyde Drexler     1.610613e+09           0
# 21           0                 NaN              NaN           0
# 22           0                 NaN              NaN           0
# 23           0                 NaN              NaN           0
# 24           0                 NaN              NaN           0
# 25           0                 NaN              NaN           0
# 26           0                 NaN              NaN           0
# 27           0                 NaN              NaN           0
# 28           0                 NaN              NaN           0
# 29           0                 NaN              NaN           0
# 30           0                 NaN              NaN         782
# 31           0                 NaN              NaN           0
# 32           0                 NaN              NaN           0
# 33           0                 NaN              NaN           0
# 34           0                 NaN              NaN           0
# 35           0                 NaN              NaN           0
# 36         722  Corliss Williamson     1.610613e+09           0
# 37           0                 NaN     1.610613e+09           0
# 38           0                 NaN              NaN           0
# 39           0                 NaN              NaN           0
# 40           0                 NaN              NaN           0
# 41           0                 NaN     1.610613e+09           0
# 42           0                 NaN              NaN           0
# 43          63       Michael Smith     1.610613e+09           0
# 44           0                 NaN              NaN           0
# 45           0                 NaN              NaN           0
# 46         722  Corliss Williamson     1.610613e+09           0
# 47           0                 NaN              NaN           0
# 48           0                 NaN              NaN           0
# 49          17       Clyde Drexler     1.610613e+09           0
