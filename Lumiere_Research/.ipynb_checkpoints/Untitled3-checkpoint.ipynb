# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import re

# %%
pd.set_option('display.max_colwidth',500)
pd.set_option('display.max_rows',500)

# %%
play = pd.read_csv("play_by_play.csv")

# %%
play = play.drop(['eventnum', 'eventmsgactiontype', 'period',
       'wctimestring', 'pctimestring', 'neutraldescription', 'person1type',
       'player1_team_id', 'player1_team_city',
       'player1_team_nickname', 'player1_team_abbreviation', 'person2type',
       'player2_team_id', 'player2_team_city',
       'player2_team_nickname', 'player2_team_abbreviation', 'person3type',
       'player3_id','player3_name','player3_team_id', 'player3_team_city',
       'player3_team_nickname', 'player3_team_abbreviation',
       'video_available_flag'], axis = 1)
play
# Out:
#            game_id  eventmsgtype  \
# 0         29600009            12
# 1         29600009            10
# 2         29600009             5
# 3         29600009             2
# 4         29600009             4
# ...            ...           ...
# 13227006  22201014             8
# 13227007  22201014             8
# 13227008  22201014             2
# 13227009  22201014             4
# 13227010  22201014            13
#
#                                              homedescription  \
# 0                                                        NaN
# 1         Jump Ball Olajuwon vs. Polynice: Tip to Williamson
# 2                                                        NaN
# 3                                MISS Olajuwon 13' Jump Shot
# 4                              Drexler REBOUND (Off:1 Def:0)
# ...                                                      ...
# 13227006                           SUB: Porter Jr. FOR Smith
# 13227007                                                 NaN
# 13227008             MISS Jokic 25' 3PT Turnaround Jump Shot
# 13227009                                     NUGGETS Rebound
# 13227010                                                 NaN
#
#                              visitordescription      score scoremargin  \
# 0                                           NaN        NaN         NaN
# 1                                           NaN        NaN         NaN
# 2         Williamson Traveling Turnover (P1.T1)        NaN         NaN
# 3                                           NaN        NaN         NaN
# 4                                           NaN        NaN         NaN
# ...                                         ...        ...         ...
# 13227006                                    NaN        NaN         NaN
# 13227007               SUB: Claxton FOR Johnson        NaN         NaN
# 13227008                                    NaN        NaN         NaN
# 13227009                                    NaN        NaN         NaN
# 13227010                                    NaN  122 - 120          -2
#
#           player1_id        player1_name  player2_id        player2_name
# 0                  0                 NaN           0                 NaN
# 1                165     Hakeem Olajuwon         178      Olden Polynice
# 2                722  Corliss Williamson           0                 NaN
# 3                165     Hakeem Olajuwon           0                 NaN
# 4                 17       Clyde Drexler           0                 NaN
# ...              ...                 ...         ...                 ...
# 13227006      202397           Ish Smith     1629008  Michael Porter Jr.
# 13227007     1629661     Cameron Johnson     1629651         Nic Claxton
# 13227008      203999        Nikola Jokic           0                 NaN
# 13227009  1610612743                 NaN           0                 NaN
# 13227010           0                 NaN           0                 NaN
#
# [13227011 rows x 10 columns]

# %%
player = pd.DataFrame(data = {'person_id' : [], 'points' : []})
player
# Out:
# Empty DataFrame
# Columns: [person_id, points]
# Index: []

# %%
count = 0
game_id = 0
game_id_index = 0
eventmsgtype = 1
scoremargin = 5
player1_id = 6
margin = 0
print("starting...")
for row in play.values:
    data = {'person_id' : 0, 'points' : 0}
    if (
        (row[eventmsgtype] == 8) | (row[eventmsgtype] == 9) | 
        (row[eventmsgtype] == 10) | (row[eventmsgtype] == 11) | 
        (row[eventmsgtype] == 12) | (row[eventmsgtype] == 13) |
        (row[eventmsgtype] == 2) | (row[eventmsgtype] == 4) |
        (row[eventmsgtype] == 5) | (row[eventmsgtype] == 6) |
        (row[eventmsgtype] == 7) | (row[eventmsgtype] == 3) 
        ):
        continue
    
    elif pd.notna(row[scoremargin]):
        if row[scoremargin] == "TIE":
            points = abs(0 - margin)
        else:
            points = abs(int(row[scoremargin]) - margin)
        if not player.loc[(player["person_id"] == row[player1_id]), "person_id"].empty:
            player.loc[(player["person_id"] == row[player1_id]), "points"] += points
        else:
            data["person_id"] = row[player1_id]
            data["person_id"] = row[player1_id]
            player.loc[(player["person_id"] == row[player1_id]), "points"] = points
            player = player.append(data, ignore_index=True)
    
    if game_id != row[game_id_index]:
        margin = 0
        game_id = row[game_id_index]
    
    if count % 100000 == 0:
        print(count)
    count += 1
print("Finished")
# Out:
# starting...
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-0e69bde58c31> in <module>
#      24         else:
#      25             points = abs(int(row[scoremargin]) - margin)
# ---> 26         if not player.loc[(player["person_id"] == row[player1_id]), "person_id"].empty:
#      27             player.loc[(player["person_id"] == row[player1_id]), "points"] += points
#      28         else:
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     808                     return section
#     809                 # This is an elided recursive call to iloc/loc
# --> 810                 return getattr(section, self.name)[new_key]
#     811
#     812         raise IndexingError("not applicable")
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#    1092
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
# --> 898         return self.obj._take_with_is_copy(inds, axis=axis)
#     899
#     900
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/series.py in _take_with_is_copy(self, indices, axis)
#     845         See the docstring of `take` for full explanation of the parameters.
#     846         """
# --> 847         return self.take(indices=indices, axis=axis)
#     848
#     849     def _ixs(self, i: int, axis: int = 0):
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/series.py in take(self, indices, axis, is_copy, **kwargs)
#     833         new_values = self._values.take(indices)
#     834
# --> 835         result = self._constructor(new_values, index=new_index, fastpath=True)
#     836         return result.__finalize__(self, method="take")
#     837
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     219             # data is an ndarray, index is defined
#     220             if not isinstance(data, SingleBlockManager):
# --> 221                 data = SingleBlockManager.from_array(data, index)
#     222             if copy:
#     223                 data = data.copy()
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1576         Constructor for if we have an array that is not yet a Block.
#    1577         """
# -> 1578         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1579         return cls(block, index)
#    1580
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2735     if klass is None:
#    2736         dtype = dtype or values.dtype
# -> 2737         klass = get_block_type(values, dtype)
#    2738
#    2739     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2699         assert not is_datetime64tz_dtype(values.dtype)
#    2700         cls = DatetimeBlock
# -> 2701     elif is_datetime64tz_dtype(values.dtype):
#    2702         cls = DatetimeTZBlock
#    2703     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_datetime64tz_dtype(arr_or_dtype)
#     417     if arr_or_dtype is None:
#     418         return False
# --> 419     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#     420
#     421
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     280         dtype = getattr(dtype, "dtype", dtype)
#     281
# --> 282         if isinstance(dtype, (ABCSeries, ABCIndexClass, ABCDataFrame, np.dtype)):
#     283             # https://github.com/pandas-dev/pandas/issues/22960
#     284             # avoid passing data to `construct_from_string`. This could
#
# ~/anaconda3/envs/tenserflow/lib/python3.6/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
# ---> 12         return getattr(inst, attr, "_typ") in comp
#      13
#      14     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
player.head(50)
# Out:
#     person_id  points
# 0        53.0   989.0
# 1        51.0  1373.0
# 2      1074.0  1060.0
# 3       722.0  1674.0
# 4       258.0   214.0
# 5        17.0  2075.0
# 6       782.0  2577.0
# 7       165.0  2295.0
# 8       970.0   458.0
# 9      1489.0   238.0
# 10      788.0  1259.0
# 11      190.0   348.0
# 12      988.0   465.0
# 13      672.0   580.0
# 14       63.0   920.0
# 15      721.0   808.0
# 16      105.0  1065.0
# 17      120.0  1327.0
# 18      703.0   345.0
# 19      297.0  2203.0
# 20      363.0  1839.0
# 21      896.0  2171.0
# 22       87.0  1417.0
# 23      173.0   613.0
# 24     1134.0  1271.0
# 25      202.0   334.0
# 26      390.0  1154.0
# 27      302.0  1727.0
# 28      895.0  1128.0
# 29      468.0   583.0
# 30      136.0  1096.0
# 31       80.0   245.0
# 32      436.0  1959.0
# 33       98.0   720.0
# 34      140.0   280.0
# 35      393.0  1537.0
# 36      358.0   576.0
# 37      185.0  2126.0
# 38      270.0   875.0
# 39      280.0   433.0
# 40     1114.0   644.0
# 41      786.0  1406.0
# 42      710.0   190.0
# 43      145.0   945.0
# 44      400.0   844.0
# 45      384.0  1043.0
# 46      265.0   467.0
# 47      216.0   513.0
# 48       43.0   630.0
# 49      121.0  2131.0
